# %% [markdown]
# ## Producer A — Kafka Event Stream Initialisation
#
# This cell initialises and runs **Producer A**, which reads camera events from `camera_event_A.csv`
# and publishes them to the Kafka topic `camera-events-A` in batches grouped by `batch_id`.
#
# ### Key Parameters
#
# | Parameter | Value | Rationale |
# |---|---|---|
# | `bootstrap_servers` | `kafka:9092` | Kafka broker address as defined in Docker Compose network. Using the service name `kafka` instead of `localhost` ensures correct container-to-container routing. |
# | `topic` | `camera-events-A` | Dedicated topic per producer isolates each camera stream, allowing the Spark consumer to subscribe selectively and apply per-stream logic. |
# | `camera_id` | `1` | Identifies the source camera for all events published by this producer, enabling traceability in the downstream violation detection logic. |
# | `batch_interval` | `5 seconds` | Events are grouped by `batch_id` and published one batch every 5 seconds. It provides a simulation of a camera emitting periodic snapshots, while giving Spark sufficient time to process each micro-batch before the next arrives. |
# | `csv_path` | `../data/camera_event_A.csv` | Relative path to the camera event dataset for Producer A, following the submission directory structure defined in the specification. |
#
# ### Execution Notes
#
# - The producer runs continuously until manually interrupted (`KeyboardInterrupt`).
# - On interrupt or error, `producer_a.close()` is called in the `finally` block to ensure the Kafka
#   producer is gracefully shut down and all buffered messages are flushed.
# - Run this notebook **concurrently** with Producer B and Producer C notebooks to simulate
#   simultaneous multi-camera event ingestion, as required by the streaming join logic in Task 2.1.2.

# %%
from pathlib import Path

from camera_event_producer import CameraEventProducer

HOST_IP = "kafka"  # Docker Compose service name
csv_path = Path("..") / "data" / "camera_event_A.csv"
producer_a = CameraEventProducer(
    bootstrap_servers=[
        "172.31.21.188:9092",
        "172.31.27.144:9093",
        "172.31.23.201:9094"
    ],
    topic="camera-events-A",
    camera_id=1,
    csv_path=str(csv_path),
    batch_interval=5
)

try:
    producer_a.publish_batches()
except KeyboardInterrupt:
    print("Producer A stopped by user")
finally:
    producer_a.close()
# Out:
# [2026-06-08T12:16:30.064401] Published batch 1 to camera-events-A (20 events)
# [2026-06-08T12:16:35.287024] Published batch 2 to camera-events-A (20 events)
# [2026-06-08T12:16:40.370455] Published batch 3 to camera-events-A (20 events)
# [2026-06-08T12:16:45.437182] Published batch 4 to camera-events-A (20 events)
# [2026-06-08T12:16:50.509299] Published batch 5 to camera-events-A (20 events)
# [2026-06-08T12:16:55.579760] Published batch 6 to camera-events-A (20 events)
# [2026-06-08T12:17:00.712415] Published batch 7 to camera-events-A (20 events)
# [2026-06-08T12:17:05.766819] Published batch 8 to camera-events-A (20 events)
# [2026-06-08T12:17:10.798313] Published batch 9 to camera-events-A (20 events)
# [2026-06-08T12:17:15.922113] Published batch 10 to camera-events-A (20 events)
# [2026-06-08T12:17:21.004068] Published batch 11 to camera-events-A (20 events)
# [2026-06-08T12:17:26.057785] Published batch 12 to camera-events-A (20 events)
# [2026-06-08T12:17:31.093128] Published batch 13 to camera-events-A (20 events)
# [2026-06-08T12:17:36.155198] Published batch 14 to camera-events-A (20 events)
# [2026-06-08T12:17:41.230219] Published batch 15 to camera-events-A (20 events)
# [2026-06-08T12:17:46.263789] Published batch 16 to camera-events-A (20 events)
# [2026-06-08T12:17:51.314955] Published batch 17 to camera-events-A (20 events)
# [2026-06-08T12:17:56.386468] Published batch 18 to camera-events-A (20 events)
# [2026-06-08T12:18:01.403203] Published batch 19 to camera-events-A (20 events)
# [2026-06-08T12:18:06.427206] Published batch 20 to camera-events-A (20 events)
# [2026-06-08T12:18:11.487905] Published batch 21 to camera-events-A (20 events)
# [2026-06-08T12:18:16.559115] Published batch 22 to camera-events-A (20 events)
# [2026-06-08T12:18:21.578095] Published batch 23 to camera-events-A (20 events)
# [2026-06-08T12:18:26.685141] Published batch 24 to camera-events-A (20 events)
# [2026-06-08T12:18:31.706721] Published batch 25 to camera-events-A (20 events)
# [2026-06-08T12:18:36.816184] Published batch 26 to camera-events-A (20 events)
# [2026-06-08T12:18:41.836461] Published batch 27 to camera-events-A (20 events)
# [2026-06-08T12:18:46.847977] Published batch 28 to camera-events-A (20 events)
# [2026-06-08T12:18:51.911819] Published batch 29 to camera-events-A (20 events)
# [2026-06-08T12:18:56.935850] Published batch 30 to camera-events-A (20 events)
# [2026-06-08T12:19:02.130725] Published batch 31 to camera-events-A (20 events)
# [2026-06-08T12:19:07.148786] Published batch 32 to camera-events-A (20 events)
# [2026-06-08T12:19:12.159219] Published batch 33 to camera-events-A (20 events)
# [2026-06-08T12:19:17.193084] Published batch 34 to camera-events-A (20 events)
# [2026-06-08T12:19:22.213989] Published batch 35 to camera-events-A (20 events)
# [2026-06-08T12:19:27.255231] Published batch 36 to camera-events-A (20 events)
# [2026-06-08T12:19:32.269995] Published batch 37 to camera-events-A (20 events)
# [2026-06-08T12:19:37.291525] Published batch 38 to camera-events-A (20 events)
# [2026-06-08T12:19:42.308134] Published batch 39 to camera-events-A (20 events)
# [2026-06-08T12:19:47.318233] Published batch 40 to camera-events-A (20 events)
# [2026-06-08T12:19:52.343820] Published batch 41 to camera-events-A (20 events)
# [2026-06-08T12:19:57.361357] Published batch 42 to camera-events-A (20 events)
# [2026-06-08T12:20:02.377482] Published batch 43 to camera-events-A (20 events)
# [2026-06-08T12:20:07.424711] Published batch 44 to camera-events-A (20 events)
# [2026-06-08T12:20:12.444189] Published batch 45 to camera-events-A (20 events)
# [2026-06-08T12:20:17.456717] Published batch 46 to camera-events-A (20 events)
# [2026-06-08T12:20:22.508415] Published batch 47 to camera-events-A (20 events)
# [2026-06-08T12:20:27.529828] Published batch 48 to camera-events-A (20 events)
# [2026-06-08T12:20:32.575429] Published batch 49 to camera-events-A (20 events)
# [2026-06-08T12:20:37.594315] Published batch 50 to camera-events-A (20 events)
# [2026-06-08T12:20:42.665536] Published batch 51 to camera-events-A (20 events)
# [2026-06-08T12:20:47.678612] Published batch 52 to camera-events-A (20 events)
# [2026-06-08T12:20:52.694737] Published batch 53 to camera-events-A (20 events)
# [2026-06-08T12:20:57.737127] Published batch 54 to camera-events-A (20 events)
# [2026-06-08T12:21:02.771256] Published batch 55 to camera-events-A (20 events)
# [2026-06-08T12:21:07.782494] Published batch 56 to camera-events-A (20 events)
# [2026-06-08T12:21:12.806116] Published batch 57 to camera-events-A (20 events)
# [2026-06-08T12:21:17.814138] Published batch 58 to camera-events-A (20 events)
# [2026-06-08T12:21:22.833381] Published batch 59 to camera-events-A (20 events)
# [2026-06-08T12:21:27.854053] Published batch 60 to camera-events-A (20 events)
# [2026-06-08T12:21:32.863166] Published batch 61 to camera-events-A (20 events)
# [2026-06-08T12:21:37.882834] Published batch 62 to camera-events-A (20 events)
# [2026-06-08T12:21:42.908276] Published batch 63 to camera-events-A (20 events)
# [2026-06-08T12:21:47.934842] Published batch 64 to camera-events-A (20 events)
# [2026-06-08T12:21:52.979182] Published batch 65 to camera-events-A (20 events)
# [2026-06-08T12:21:58.004477] Published batch 66 to camera-events-A (20 events)
# [2026-06-08T12:22:03.017619] Published batch 67 to camera-events-A (20 events)
# [2026-06-08T12:22:08.078969] Published batch 68 to camera-events-A (20 events)
# [2026-06-08T12:22:13.135512] Published batch 69 to camera-events-A (20 events)
# [2026-06-08T12:22:18.168267] Published batch 70 to camera-events-A (20 events)
# [2026-06-08T12:22:23.238809] Published batch 71 to camera-events-A (20 events)
# [2026-06-08T12:22:28.259952] Published batch 72 to camera-events-A (20 events)
# [2026-06-08T12:22:33.283070] Published batch 73 to camera-events-A (20 events)
# [2026-06-08T12:22:38.323086] Published batch 74 to camera-events-A (20 events)
# [2026-06-08T12:22:43.375714] Published batch 75 to camera-events-A (20 events)
# [2026-06-08T12:22:48.407628] Published batch 76 to camera-events-A (20 events)
# [2026-06-08T12:22:53.425981] Published batch 77 to camera-events-A (20 events)
# [2026-06-08T12:22:58.444024] Published batch 78 to camera-events-A (20 events)
# [2026-06-08T12:23:03.465242] Published batch 79 to camera-events-A (20 events)
# [2026-06-08T12:23:08.491635] Published batch 80 to camera-events-A (20 events)
# [2026-06-08T12:23:13.524502] Published batch 81 to camera-events-A (20 events)
# [2026-06-08T12:23:18.545462] Published batch 82 to camera-events-A (20 events)
# [2026-06-08T12:23:23.556479] Published batch 83 to camera-events-A (20 events)
# [2026-06-08T12:23:28.576983] Published batch 84 to camera-events-A (20 events)
# [2026-06-08T12:23:33.591801] Published batch 85 to camera-events-A (20 events)
# [2026-06-08T12:23:38.609631] Published batch 86 to camera-events-A (20 events)
# [2026-06-08T12:23:43.617213] Published batch 87 to camera-events-A (20 events)
# [2026-06-08T12:23:48.645323] Published batch 88 to camera-events-A (20 events)
# [2026-06-08T12:23:53.668319] Published batch 89 to camera-events-A (20 events)
# [2026-06-08T12:23:58.687313] Published batch 90 to camera-events-A (20 events)
# [2026-06-08T12:24:03.700310] Published batch 91 to camera-events-A (20 events)
# [2026-06-08T12:24:08.720038] Published batch 92 to camera-events-A (20 events)
# [2026-06-08T12:24:13.729077] Published batch 93 to camera-events-A (20 events)
# [2026-06-08T12:24:18.762105] Published batch 94 to camera-events-A (20 events)
# [2026-06-08T12:24:23.794068] Published batch 95 to camera-events-A (20 events)
# [2026-06-08T12:24:28.806209] Published batch 96 to camera-events-A (20 events)
# [2026-06-08T12:24:33.823472] Published batch 97 to camera-events-A (20 events)
# [2026-06-08T12:24:38.833456] Published batch 98 to camera-events-A (20 events)
# [2026-06-08T12:24:43.860656] Published batch 99 to camera-events-A (20 events)
# [2026-06-08T12:24:48.883298] Published batch 100 to camera-events-A (20 events)
# [2026-06-08T12:24:53.911004] Published batch 101 to camera-events-A (20 events)
# [2026-06-08T12:24:58.930204] Published batch 102 to camera-events-A (20 events)
# [2026-06-08T12:25:03.955670] Published batch 103 to camera-events-A (20 events)
# [2026-06-08T12:25:08.964537] Published batch 104 to camera-events-A (20 events)
# [2026-06-08T12:25:13.986213] Published batch 105 to camera-events-A (20 events)
# [2026-06-08T12:25:19.013286] Published batch 106 to camera-events-A (20 events)
# [2026-06-08T12:25:24.030768] Published batch 107 to camera-events-A (20 events)
# [2026-06-08T12:25:29.083869] Published batch 108 to camera-events-A (20 events)
# [2026-06-08T12:25:34.104209] Published batch 109 to camera-events-A (20 events)
# [2026-06-08T12:25:39.146544] Published batch 110 to camera-events-A (20 events)
# [2026-06-08T12:25:44.166182] Published batch 111 to camera-events-A (20 events)
# [2026-06-08T12:25:49.180663] Published batch 112 to camera-events-A (20 events)
# [2026-06-08T12:25:54.198033] Published batch 113 to camera-events-A (20 events)
# [2026-06-08T12:25:59.211074] Published batch 114 to camera-events-A (20 events)
# [2026-06-08T12:26:04.224997] Published batch 115 to camera-events-A (20 events)
# [2026-06-08T12:26:09.262663] Published batch 116 to camera-events-A (20 events)
# [2026-06-08T12:26:14.272795] Published batch 117 to camera-events-A (20 events)
# [2026-06-08T12:26:19.280363] Published batch 118 to camera-events-A (20 events)
# [2026-06-08T12:26:24.300339] Published batch 119 to camera-events-A (20 events)
# [2026-06-08T12:26:29.311639] Published batch 120 to camera-events-A (20 events)
# [2026-06-08T12:26:34.346844] Published batch 121 to camera-events-A (20 events)
# [2026-06-08T12:26:39.382343] Published batch 122 to camera-events-A (20 events)
# [2026-06-08T12:26:44.388188] Published batch 123 to camera-events-A (20 events)
# [2026-06-08T12:26:49.404063] Published batch 124 to camera-events-A (20 events)
# [2026-06-08T12:26:54.432357] Published batch 125 to camera-events-A (20 events)
# [2026-06-08T12:26:59.441517] Published batch 126 to camera-events-A (20 events)
# [2026-06-08T12:27:04.470862] Published batch 127 to camera-events-A (20 events)
# [2026-06-08T12:27:09.487754] Published batch 128 to camera-events-A (20 events)
# [2026-06-08T12:27:14.536602] Published batch 129 to camera-events-A (20 events)
# [2026-06-08T12:27:19.559403] Published batch 130 to camera-events-A (20 events)
# [2026-06-08T12:27:24.588284] Published batch 131 to camera-events-A (20 events)
# [2026-06-08T12:27:29.603409] Published batch 132 to camera-events-A (20 events)
# [2026-06-08T12:27:34.619082] Published batch 133 to camera-events-A (20 events)
# [2026-06-08T12:27:39.695766] Published batch 134 to camera-events-A (20 events)
# [2026-06-08T12:27:44.762442] Published batch 135 to camera-events-A (20 events)
# [2026-06-08T12:27:49.805089] Published batch 136 to camera-events-A (20 events)
# [2026-06-08T12:27:54.841277] Published batch 137 to camera-events-A (20 events)
# [2026-06-08T12:27:59.859881] Published batch 138 to camera-events-A (20 events)
# [2026-06-08T12:28:04.969141] Published batch 139 to camera-events-A (20 events)
# [2026-06-08T12:28:10.004544] Published batch 140 to camera-events-A (20 events)
