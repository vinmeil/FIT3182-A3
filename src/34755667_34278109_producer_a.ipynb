# %% [markdown]
# ## Producer A — Kafka Event Stream Initialisation
#
# This cell initialises and runs **Producer A**, which reads camera events from `camera_event_A.csv`
# and publishes them to the Kafka topic `camera-events-A` in batches grouped by `batch_id`.
#
# ### Key Parameters
#
# | Parameter | Value | Rationale |
# |---|---|---|
# | `bootstrap_servers` | `kafka:9092` | Kafka broker address as defined in Docker Compose network. Using the service name `kafka` instead of `localhost` ensures correct container-to-container routing. |
# | `topic` | `camera-events-A` | Dedicated topic per producer isolates each camera stream, allowing the Spark consumer to subscribe selectively and apply per-stream logic. |
# | `camera_id` | `1` | Identifies the source camera for all events published by this producer, enabling traceability in the downstream violation detection logic. |
# | `batch_interval` | `5 seconds` | Events are grouped by `batch_id` and published one batch every 5 seconds. It provides a simulation of a camera emitting periodic snapshots, while giving Spark sufficient time to process each micro-batch before the next arrives. |
# | `csv_path` | `../data/camera_event_A.csv` | Relative path to the camera event dataset for Producer A, following the submission directory structure defined in the specification. |
#
# ### Execution Notes
#
# - The producer runs continuously until manually interrupted (`KeyboardInterrupt`).
# - On interrupt or error, `producer_a.close()` is called in the `finally` block to ensure the Kafka
#   producer is gracefully shut down and all buffered messages are flushed.
# - Run this notebook **concurrently** with Producer B and Producer C notebooks to simulate
#   simultaneous multi-camera event ingestion, as required by the streaming join logic in Task 2.1.2.

# %%
from pathlib import Path

from camera_event_producer import CameraEventProducer

HOST_IP = "kafka"  # Docker Compose service name
csv_path = Path("..") / "data" / "camera_event_A.csv"
producer_a = CameraEventProducer(
    bootstrap_servers=[f"{HOST_IP}:9092"],
    topic="camera-events-A",
    camera_id=1,
    csv_path=str(csv_path),
    batch_interval=5
)

try:
    producer_a.publish_batches()
except KeyboardInterrupt:
    print("Producer A stopped by user")
finally:
    producer_a.close()
# Out:
# [2026-05-25T14:54:15.591196] Published batch 1 to camera-events-A (20 events)
# [2026-05-25T14:54:20.611786] Published batch 2 to camera-events-A (20 events)
# [2026-05-25T14:54:25.640578] Published batch 3 to camera-events-A (20 events)
# [2026-05-25T14:54:30.658343] Published batch 4 to camera-events-A (20 events)
# [2026-05-25T14:54:35.677523] Published batch 5 to camera-events-A (20 events)
# [2026-05-25T14:54:40.690468] Published batch 6 to camera-events-A (20 events)
# [2026-05-25T14:54:45.709027] Published batch 7 to camera-events-A (20 events)
# [2026-05-25T14:54:50.719822] Published batch 8 to camera-events-A (20 events)
# [2026-05-25T14:54:55.733973] Published batch 9 to camera-events-A (20 events)
# [2026-05-25T14:55:00.754026] Published batch 10 to camera-events-A (20 events)
# [2026-05-25T14:55:05.767833] Published batch 11 to camera-events-A (20 events)
# [2026-05-25T14:55:10.779845] Published batch 12 to camera-events-A (20 events)
# [2026-05-25T14:55:15.794515] Published batch 13 to camera-events-A (20 events)
# [2026-05-25T14:55:20.802152] Published batch 14 to camera-events-A (20 events)
# [2026-05-25T14:55:25.810420] Published batch 15 to camera-events-A (20 events)
# [2026-05-25T14:55:30.822024] Published batch 16 to camera-events-A (20 events)
# [2026-05-25T14:55:35.833282] Published batch 17 to camera-events-A (20 events)
# [2026-05-25T14:55:40.841213] Published batch 18 to camera-events-A (20 events)
# [2026-05-25T14:55:45.853369] Published batch 19 to camera-events-A (20 events)
# [2026-05-25T14:55:50.871404] Published batch 20 to camera-events-A (20 events)
# [2026-05-25T14:55:55.879790] Published batch 21 to camera-events-A (20 events)
# [2026-05-25T14:56:00.892878] Published batch 22 to camera-events-A (20 events)
# [2026-05-25T14:56:05.908822] Published batch 23 to camera-events-A (20 events)
# [2026-05-25T14:56:10.958885] Published batch 24 to camera-events-A (20 events)
# [2026-05-25T14:56:15.974585] Published batch 25 to camera-events-A (20 events)
# [2026-05-25T14:56:20.992270] Published batch 26 to camera-events-A (20 events)
# [2026-05-25T14:56:26.006584] Published batch 27 to camera-events-A (20 events)
# [2026-05-25T14:56:31.017014] Published batch 28 to camera-events-A (20 events)
# [2026-05-25T14:56:36.032530] Published batch 29 to camera-events-A (20 events)
# [2026-05-25T14:56:41.049984] Published batch 30 to camera-events-A (20 events)
# [2026-05-25T14:56:46.066908] Published batch 31 to camera-events-A (20 events)
# [2026-05-25T14:56:51.079465] Published batch 32 to camera-events-A (20 events)
# [2026-05-25T14:56:56.109409] Published batch 33 to camera-events-A (20 events)
# [2026-05-25T14:57:01.120074] Published batch 34 to camera-events-A (20 events)
# [2026-05-25T14:57:06.129684] Published batch 35 to camera-events-A (20 events)
# [2026-05-25T14:57:11.138634] Published batch 36 to camera-events-A (20 events)
# [2026-05-25T14:57:16.147975] Published batch 37 to camera-events-A (20 events)
# [2026-05-25T14:57:21.153688] Published batch 38 to camera-events-A (20 events)
# [2026-05-25T14:57:26.167008] Published batch 39 to camera-events-A (20 events)
# [2026-05-25T14:57:31.173484] Published batch 40 to camera-events-A (20 events)
# [2026-05-25T14:57:36.186358] Published batch 41 to camera-events-A (20 events)
# [2026-05-25T14:57:41.206876] Published batch 42 to camera-events-A (20 events)
# [2026-05-25T14:57:46.228077] Published batch 43 to camera-events-A (20 events)
# [2026-05-25T14:57:51.236639] Published batch 44 to camera-events-A (20 events)
# [2026-05-25T14:57:56.251687] Published batch 45 to camera-events-A (20 events)
# [2026-05-25T14:58:01.275743] Published batch 46 to camera-events-A (20 events)
# [2026-05-25T14:58:06.288403] Published batch 47 to camera-events-A (20 events)
# [2026-05-25T14:58:11.302615] Published batch 48 to camera-events-A (20 events)
# [2026-05-25T14:58:16.310873] Published batch 49 to camera-events-A (20 events)
# [2026-05-25T14:58:21.320789] Published batch 50 to camera-events-A (20 events)
# [2026-05-25T14:58:26.350350] Published batch 51 to camera-events-A (20 events)
# [2026-05-25T14:58:31.373278] Published batch 52 to camera-events-A (20 events)
# [2026-05-25T14:58:36.392219] Published batch 53 to camera-events-A (20 events)
# [2026-05-25T14:58:41.401233] Published batch 54 to camera-events-A (20 events)
# [2026-05-25T14:58:46.411462] Published batch 55 to camera-events-A (20 events)
