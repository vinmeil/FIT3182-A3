# %%
from pathlib import Path

from camera_event_producer import CameraEventProducer

HOST_IP = "kafka"  # Docker Compose service name
csv_path = Path("..") / "data" / "camera_event_C.csv"
producer_c = CameraEventProducer(
    bootstrap_servers=[f"{HOST_IP}:9092"],
    topic="camera-events-C",
    camera_id=3,
    csv_path=str(csv_path),
    batch_interval=5
)

try:
    producer_c.publish_batches()
except KeyboardInterrupt:
    print("Producer C stopped by user")
finally:
    producer_c.close()
# Out:
# [2026-05-12T06:52:19.005127] Published batch 1 to camera-events-C (1 events)
# [2026-05-12T06:52:24.013034] Published batch 2 to camera-events-C (1 events)
# [2026-05-12T06:52:29.020236] Published batch 3 to camera-events-C (2 events)
# [2026-05-12T06:52:34.027151] Published batch 4 to camera-events-C (2 events)
# [2026-05-12T06:52:39.035040] Published batch 5 to camera-events-C (1 events)
# [2026-05-12T06:52:44.043143] Published batch 6 to camera-events-C (1 events)
# [2026-05-12T06:52:49.051128] Published batch 7 to camera-events-C (2 events)
# [2026-05-12T06:52:54.058703] Published batch 8 to camera-events-C (1 events)
# [2026-05-12T06:52:59.063261] Published batch 9 to camera-events-C (2 events)
# [2026-05-12T06:53:04.071278] Published batch 10 to camera-events-C (2 events)
# [2026-05-12T06:53:09.080827] Published batch 11 to camera-events-C (1 events)
# [2026-05-12T06:53:14.086847] Published batch 12 to camera-events-C (1 events)
# [2026-05-12T06:53:19.095146] Published batch 13 to camera-events-C (1 events)
# [2026-05-12T06:53:24.102748] Published batch 14 to camera-events-C (1 events)
# [2026-05-12T06:53:29.110701] Published batch 15 to camera-events-C (1 events)
# [2026-05-12T06:53:34.118726] Published batch 16 to camera-events-C (1 events)
# [2026-05-12T06:53:39.127440] Published batch 17 to camera-events-C (1 events)
# [2026-05-12T06:53:44.135658] Published batch 18 to camera-events-C (2 events)
# [2026-05-12T06:53:49.143798] Published batch 19 to camera-events-C (1 events)
# [2026-05-12T06:53:54.151045] Published batch 20 to camera-events-C (1 events)
# [2026-05-12T06:53:59.159060] Published batch 21 to camera-events-C (1 events)
