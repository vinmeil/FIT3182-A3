# %%
from pathlib import Path

from camera_event_producer import CameraEventProducer

HOST_IP = "kafka"  # Docker Compose service name
csv_path = Path("..") / "data" / "camera_event_C.csv"
producer_c = CameraEventProducer(
    bootstrap_servers=[f"{HOST_IP}:9092"],
    topic="camera-events-C",
    camera_id=3,
    csv_path=str(csv_path),
    batch_interval=5
)

try:
    producer_c.publish_batches()
except KeyboardInterrupt:
    print("Producer C stopped by user")
finally:
    producer_c.close()
# Out:
# [2026-05-11T08:50:28.422456] Published batch 1 to camera-events-C (1 events)
# [2026-05-11T08:50:33.430261] Published batch 2 to camera-events-C (1 events)
# [2026-05-11T08:50:38.435973] Published batch 3 to camera-events-C (2 events)
# [2026-05-11T08:50:43.443492] Published batch 4 to camera-events-C (2 events)
# [2026-05-11T08:50:48.453726] Published batch 5 to camera-events-C (1 events)
# [2026-05-11T08:50:53.461452] Published batch 6 to camera-events-C (1 events)
# [2026-05-11T08:50:58.469351] Published batch 7 to camera-events-C (2 events)
# [2026-05-11T08:51:03.477670] Published batch 8 to camera-events-C (1 events)
# [2026-05-11T08:51:08.487468] Published batch 9 to camera-events-C (2 events)
# [2026-05-11T08:51:13.495498] Published batch 10 to camera-events-C (2 events)
# [2026-05-11T08:51:18.503423] Published batch 11 to camera-events-C (1 events)
# [2026-05-11T08:51:23.511366] Published batch 12 to camera-events-C (1 events)
# [2026-05-11T08:51:28.514831] Published batch 13 to camera-events-C (1 events)
# [2026-05-11T08:51:33.522220] Published batch 14 to camera-events-C (1 events)
# [2026-05-11T08:51:38.528780] Published batch 15 to camera-events-C (1 events)
# [2026-05-11T08:51:43.536757] Published batch 16 to camera-events-C (1 events)
# [2026-05-11T08:51:48.544119] Published batch 17 to camera-events-C (1 events)
# [2026-05-11T08:51:53.555158] Published batch 18 to camera-events-C (2 events)
# [2026-05-11T08:51:58.563006] Published batch 19 to camera-events-C (1 events)
# [2026-05-11T08:52:03.567056] Published batch 20 to camera-events-C (1 events)
# [2026-05-11T08:52:08.573690] Published batch 21 to camera-events-C (1 events)
# [2026-05-11T08:52:13.584199] Published batch 22 to camera-events-C (1 events)
# [2026-05-11T08:52:18.599097] Published batch 23 to camera-events-C (2 events)
# [2026-05-11T08:52:23.609017] Published batch 24 to camera-events-C (2 events)
# [2026-05-11T08:52:28.618066] Published batch 25 to camera-events-C (2 events)
# [2026-05-11T08:52:33.625854] Published batch 26 to camera-events-C (1 events)
# [2026-05-11T08:52:38.631801] Published batch 27 to camera-events-C (1 events)
# [2026-05-11T08:52:43.641968] Published batch 28 to camera-events-C (2 events)
# [2026-05-11T08:52:48.655859] Published batch 29 to camera-events-C (2 events)
# [2026-05-11T08:52:53.666501] Published batch 30 to camera-events-C (1 events)
# [2026-05-11T08:52:58.686184] Published batch 31 to camera-events-C (2 events)
