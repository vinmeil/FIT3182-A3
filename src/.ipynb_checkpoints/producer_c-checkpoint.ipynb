# %%
from pathlib import Path

from camera_event_producer import CameraEventProducer

HOST_IP = "kafka"  # Docker Compose service name
csv_path = Path("..") / "data" / "camera_event_C.csv"
producer_c = CameraEventProducer(
    bootstrap_servers=[f"{HOST_IP}:9092"],
    topic="camera-events-C",
    camera_id=3,
    csv_path=str(csv_path),
    batch_interval=5
)

try:
    producer_c.publish_batches()
except KeyboardInterrupt:
    print("Producer C stopped by user")
finally:
    producer_c.close()
# Out:
# [2026-05-11T07:34:57.721881] Published batch 1 to camera-events-C (1 events)
# [2026-05-11T07:35:02.730212] Published batch 2 to camera-events-C (1 events)
# [2026-05-11T07:35:07.738210] Published batch 3 to camera-events-C (2 events)
# [2026-05-11T07:35:12.742799] Published batch 4 to camera-events-C (2 events)
# [2026-05-11T07:35:17.752865] Published batch 5 to camera-events-C (1 events)
# [2026-05-11T07:35:22.761155] Published batch 6 to camera-events-C (1 events)
# [2026-05-11T07:35:27.769453] Published batch 7 to camera-events-C (2 events)
# [2026-05-11T07:35:32.777665] Published batch 8 to camera-events-C (1 events)
# [2026-05-11T07:35:37.786320] Published batch 9 to camera-events-C (2 events)
# [2026-05-11T07:35:42.794680] Published batch 10 to camera-events-C (2 events)
# [2026-05-11T07:35:47.803653] Published batch 11 to camera-events-C (1 events)
# [2026-05-11T07:35:52.812059] Published batch 12 to camera-events-C (1 events)
# [2026-05-11T07:35:57.820173] Published batch 13 to camera-events-C (1 events)
# [2026-05-11T07:36:02.829449] Published batch 14 to camera-events-C (1 events)
# [2026-05-11T07:36:07.838699] Published batch 15 to camera-events-C (1 events)
# [2026-05-11T07:36:12.848013] Published batch 16 to camera-events-C (1 events)
# [2026-05-11T07:36:17.857115] Published batch 17 to camera-events-C (1 events)
# [2026-05-11T07:36:22.866982] Published batch 18 to camera-events-C (2 events)
# [2026-05-11T07:36:27.877079] Published batch 19 to camera-events-C (1 events)
# [2026-05-11T07:36:32.886127] Published batch 20 to camera-events-C (1 events)
# [2026-05-11T07:36:37.896092] Published batch 21 to camera-events-C (1 events)
# [2026-05-11T07:36:42.904922] Published batch 22 to camera-events-C (1 events)
# [2026-05-11T07:36:47.913573] Published batch 23 to camera-events-C (2 events)
