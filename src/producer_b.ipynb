# %%
from pathlib import Path

from camera_event_producer import CameraEventProducer

HOST_IP = "kafka"  # Docker Compose service name
csv_path = Path("..") / "data" / "camera_event_B.csv"
producer_b = CameraEventProducer(
    bootstrap_servers=[f"{HOST_IP}:9092"],
    topic="camera-events-B",
    camera_id=2,
    csv_path=str(csv_path),
    batch_interval=5
)

try:
    producer_b.publish_batches()
except KeyboardInterrupt:
    print("Producer B stopped by user")
finally:
    producer_b.close()
# Out:
# [2026-05-12T06:52:23.344958] Published batch 1 to camera-events-B (5 events)
# [2026-05-12T06:52:28.352085] Published batch 2 to camera-events-B (1 events)
# [2026-05-12T06:52:33.358892] Published batch 3 to camera-events-B (1 events)
# [2026-05-12T06:52:38.367631] Published batch 4 to camera-events-B (4 events)
# [2026-05-12T06:52:43.375011] Published batch 5 to camera-events-B (4 events)
# [2026-05-12T06:52:48.383427] Published batch 6 to camera-events-B (2 events)
# [2026-05-12T06:52:53.391708] Published batch 7 to camera-events-B (3 events)
# [2026-05-12T06:52:58.399856] Published batch 8 to camera-events-B (1 events)
# [2026-05-12T06:53:03.404966] Published batch 9 to camera-events-B (2 events)
# [2026-05-12T06:53:08.416185] Published batch 10 to camera-events-B (2 events)
# [2026-05-12T06:53:13.423949] Published batch 11 to camera-events-B (1 events)
# [2026-05-12T06:53:18.430889] Published batch 12 to camera-events-B (1 events)
# [2026-05-12T06:53:23.434282] Published batch 13 to camera-events-B (1 events)
# [2026-05-12T06:53:28.442320] Published batch 14 to camera-events-B (1 events)
# [2026-05-12T06:53:33.447119] Published batch 15 to camera-events-B (2 events)
# [2026-05-12T06:53:38.455253] Published batch 16 to camera-events-B (2 events)
# [2026-05-12T06:53:43.462833] Published batch 17 to camera-events-B (1 events)
# [2026-05-12T06:53:48.468681] Published batch 18 to camera-events-B (1 events)
# [2026-05-12T06:53:53.475307] Published batch 19 to camera-events-B (4 events)
# [2026-05-12T06:53:58.483657] Published batch 20 to camera-events-B (2 events)
